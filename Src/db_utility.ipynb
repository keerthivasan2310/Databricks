# %%
print("data")

# %% [markdown]
# # dbutils

# %% [markdown]
# ## dbutils.fs()

# %%
dbutils.fs.ls("/Workspace/Users/keerthivasan.v@diggibyte.com/Databricks/Src/")

# %%
dbutils.fs.mkdirs("/Workspace/Users/keerthivasan.v@diggibyte.com/Databricks/myfolder/archive")

# %%
dbutils.fs.cp("/Volumes/workspace/default/vol_1/emp.csv","/Workspace/Users/keerthivasan.v@diggibyte.com/Databricks/myfolder/employee.csv")

# %%
dbutils.fs.rm("/Workspace/Users/keerthivasan.v@diggibyte.com/Databricks/myfolder/employee.csv")

# %%
dbutils.fs.head("/Volumes/workspace/default/vol_1/emp.csv")

# %% [markdown]
# ## dbutils.notebook()

# %%
dbutils.notebook.run("/Workspace/Users/keerthivasan.v@diggibyte.com/db_util_note",10)

# %%
output = dbutils.notebook.run(
"/Workspace/Users/keerthivasan.v@diggibyte.com/db_util_note",
60,
{"name":"Keerthi"}
)

print(output)

# %% [markdown]
# ## widgets

# %%
dbutils.widgets.value("age",20)

# %%
dbutils.widgets.dropdown("country","India",["India","USA","UK"])

# %%
dbutils.widgets.combobox("city","Chennai",["Chennai","Delhi","Mumbai"])

# %%
dbutils.widgets.multiselect("languages","Python",["Python","SQL","Scala"])

# %%
dbutils.widgets.getAll()

# %% [markdown]
# ## library

# %%
# %pip install pandas

# %%
dbutils.library.restartPython()

# %%
dbutils.fs.help()

# %%
dbutils.notebook.help()

# %%
dbutils.widgets.help()

# %%
dbutils.fs.ls("dbfs:/")
